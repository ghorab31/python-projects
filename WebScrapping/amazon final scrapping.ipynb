# %%
import requests
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
amazon_get=requests.get("https://www.amazon.eg/-/en/s?k=laptops&page=1&pages=2&pages=31EO2IWBOQN68A&qid=1735816414&sprefix=laptop%2Caps%2C125&ref=sr_pg_1")
amazon_get
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(amazon_get.text,"html.parser")
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-ae"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <!-- sp:end-feature:csm:head-open-part2 -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
trial=soup.find_all('div',attrs={'class':'puis-card-container s-card-container s-overflow-hidden aok-relative puis-expand-height puis-include-content-margin puis puis-v1mhuqsk2j2j3x2l2guv52idafz s-latency-cf-section puis-card-border'})
trial
# Out:
# [<div class="puis-card-container s-card-container s-overflow-hidden aok-relative puis-expand-height puis-include-content-margin puis puis-v1mhuqsk2j2j3x2l2guv52idafz s-latency-cf-section puis-card-border" data-cy="asin-faceout-container" data-dib-asin="B0CQFCNBT4" data-dib-organic="true"><div class="a-section a-spacing-base"><div class="s-product-image-container aok-relative s-text-center s-image-overlay-grey puis-image-overlay-grey s-padding-left-small s-padding-right-small puis-spacing-small s-height-equalized puis puis-v1mhuqsk2j2j3x2l2guv52idafz" data-cy="image-container"><span class="rush-component" data-component-type="s-product-image" data-render-id="r2z5vlzpgs5sue2kn4cwn72wrl8" data-version-id="v1mhuqsk2j2j3x2l2guv52idafz"><a class="a-link-normal s-no-outline" href="/-/en/Dell-Vostro-3520-Laptop-FingerPrint/dp/B0CQFCNBT4" tabindex="-1"><div class="a-section aok-relative s-image-square-aspect"><img alt='Dell Vostro 3520 Laptop - 12th Intel Core i5-1235U 10-Cores, 8GB RAM, 512G
# ...

# %%
link=trial[0].find_all('a',attrs={'class':'a-link-normal s-line-clamp-4 s-link-style a-text-normal'})

# %%
##link
amazon=link[0] 
amazonlink=amazon.attrs
amazongetlink='https://www.amazon.eg/'+amazonlink['href']
amazongetlink
# Out:
# 'https://www.amazon.eg//-/en/Dell-Vostro-3520-Laptop-FingerPrint/dp/B0CQFCNBT4'

# %%
#name
amazonname=trial[2].find('h2',attrs={'class':'a-size-base-plus a-spacing-none a-color-base a-text-normal'})
laptopname=amazonname['aria-label'].replace(',',' and')
laptopname
# Out:
# 'Lenovo IdeaPad Slim 3 15IRH8 Intel Core i5-13420H 512GB SSD 8GB RAM Intel UHD Graphics 15.6" Windows 11 Laptop and Arctic Grey'

# %%
amazonname.text
# Out:
# 'Lenovo IdeaPad Slim 3 15IRH8 Intel Core i5-13420H 512GB SSD 8GB RAM Intel UHD Graphics 15.6" Windows 11 Laptop, Arctic Grey'

# %%
#ratingnumber
rating=trial[0].find_all('span',attrs={'class':'a-size-base s-underline-text'})
ratingnumber=int(rating[0].text)
ratingnumber
# Out:
# 20

# %%
## Amazon ratingLINK
ratinglink=trial[0].find('a',attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style'})
amazon_rating_link='https://www.amazon.eg/'+ratinglink['href']

# %%
price=trial[0].find('span',attrs={'class':'a-price'})
laptop_price=price.find('span',attrs={'class':'a-offscreen'})
edited=laptop_price.text.replace('\u200f',' ')
laptopfixedprice=edited.replace('\xa0',' ')
amazon_price1=laptopfixedprice.replace('EGP',' ').strip()
amazonprice0=amazon_price1.replace(',','').strip()
amazonprice=float(amazonprice0)

# %%
subscription=trial[0].find_all('div',attrs={'class':'a-row a-color-base udm-primary-delivery-message'})
deliverytype=subscription[0].text.strip()
deliverytype
# Out:
# 'FREE delivery'

# %%
productlink=requests.get(amazongetlink)
productsoup=BeautifulSoup(productlink.text,'html.parser')
productdata=productsoup.find_all('div',attrs={'class':'celwidget','id':'productOverview_feature_div'})

# %%
pagenumber=soup.find('span',attrs={'class':'s-pagination-item s-pagination-disabled'})
numberofpages=int(pagenumber.text)
numberofpages
# Out:
# 7

# %%
productlink=requests.get(amazongetlink)
productsoup=BeautifulSoup(productlink.text,'html.parser')
productdata=productsoup.find('div',attrs={'id':'productOverview_feature_div'})

brandname=productdata.find('tr',attrs={'class':'a-spacing-small po-brand'})
brandnametext=brandname.text.replace('Brand Name','').strip()
displaysize=productdata.find('tr',attrs={'class':'a-spacing-small po-display.size'}).text.strip()
harddisk=productdata.find('tr',attrs={'class':'a-spacing-small po-hard_disk.size'}).text.strip()
cpumodel=productdata.find('tr',attrs={'class':'a-spacing-small po-cpu_model.family'})
cpumodeltext=cpumodel.text.strip()
ram=productdata.find('tr',attrs={'class':'a-spacing-small po-ram_memory.installed_size'})
ramtext=ram.text.strip()
operating=productdata.find('tr',attrs={'class':'a-spacing-small po-operating_system'})
operating=operating.text.strip()
Specialfeatures=productdata.find('tr',attrs={'class':'a-spacing-small po-special_feature'})
specialfeaturestext=Specialfeatures.text.strip()
graphics=productdata.find('tr',attrs={'class':'a-spacing-small po-graphics_description'})
graphicstext=graphics.text.strip()
resoultion=productdata.find('tr',attrs={'class':'a-spacing-small po-resolution'})
resoultiontext=resoultion.text.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 20
#      18 graphicstext=graphics.text.strip()
#      19 resoultion=productdata.find('tr',attrs={'class':'a-spacing-small po-resolution'})
# ---> 20 resoultiontext=resoultion.text.strip()
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# Out:
# []

# %%
productlink=requests.get(amazongetlink)
productsoup=BeautifulSoup(productlink.text,'html.parser')
productdata=productsoup.find('div',attrs={'id':'productOverview_feature_div'})
resoultion=productdata.find('tr',attrs={'class':'a-spacing-small po-resolution'})
type(resoultion)
# Out:
# NoneType

# %%
productlink=requests.get(amazongetlink)
productsoup=BeautifulSoup(productlink.text,'html.parser')
productdata=productsoup.find_all('div',attrs={'class':'a-section a-spacing-small a-spacing-top-small'})
specs=""
productcategory=""
catlist=[]
listtdata=[]
testing=("")
for i in range(len(productdata)):
    products=productdata[i].find_all('span',attrs={'class':'a-size-base po-break-word'})
for p in range(len(products)):
  specs=specs+'/'+products[p].text
  specs=specs.replace(",","").strip()
  product_data=products[p].text.strip()
  listtdata.append(product_data) 
  x=products[p].text
  brandname=products[0].text.replace(",","").strip()
  if brandname:
     brandname=products[0].text.replace(",","").strip()
  else:
    print(brandname[p])
    modelname=products[1].text.replace(",","").strip()
    if modelname:
      model=products[1].text.replace(",","").strip()
    else:
      print(modelname[2])
    screensize=products[3].text.replace(",","").strip()
    if screensize:
      screensize=products[3].text.replace(",","").strip()
    else:
      print(screensize[3])
    color=products[4].text.replace(",","").strip()
    if color:
      color=products[4].text.replace(",","").strip()
    else:
      print(color[p])
    harddisk=products[5].text.replace(",","").strip()
    if harddisk:
      harddisk=products[5].text.replace(",","").strip()
    else:
      print(harddisk[p])
    cpumodel=products[6].text.replace(",","").strip()
    if cpumodel:
      cpumodel=products[6].text.replace(",","").strip()
    else:
      print(cpumodel[p])
    ram=product[7].text.replace(",","").strip()
    if ram:
      ram=products[[7]].text.replace(",","").strip()
    else:
      print(ram[p])
    operating=products[8].text.replace(",","").strip()
    if operating:
      operating=products[8].text.replace(",","").strip()
    else:
      print(operating[p])
    specialfeatures=products[8].text.replace(",","").strip()  
    if specialfeatures:
      specialfeatures=products[8].text.replace(",","").strip()
    else:
      print(specialfeatures[p])
    if len(products)>9:
      z=(products[6])
    else:
      print ("not true")
      print(z)

# %%
amazon=link[0] 
amazonlink=amazon.attrs
amazongetlink='https://www.amazon.eg/'+amazonlink['href']
amazongetlink
productlink=requests.get(amazongetlink)
productsoup=BeautifulSoup(productlink.text,'html.parser')
new2=productsoup.find('div',attrs={'class':'a-expander-collapsed-height a-row a-expander-container a-spacing-none a-expander-partial-collapse-container'})
new3=new2.find_all('tr')
modelname=""
newcat=[]
labelll=new3[9].find_all('span')
labelll[0].text
# Out:
# 'Graphics Description'

# %%
for i in range(len(new3)):
    brandnamee=""
    model=""
    screensize=""
    color=""
    harddisksize=""
    cpumodel=""
    ram=""
    operating=""
    special=""
    graphicdescription=""
    q=new3[9].find_all('td')
    label=q[0].text.strip().lower()
    #brandname
    if label=='brand name':
        brandnamee=brandnamee+(q[1].text.strip())
        print(brandnamee)
        break
    else:
        newcat.append(label)
    if label=='model name':
        model=model+(q[1].text.strip())
        print(model)
        break
    else:
        newcat.append(label)
    if label=='screen size':
        screensize=screensize+(q[1].text.strip())
        print(screensize)
        break
    else:
        newcat.append(label)
    if label=='color':
        color=color+(q[1].text.strip())
        print(color)
        break
    else:
        newcat.append(label)
    if label=='hard disk size':
        harddisksize=harddisksize+(q[1].text.strip())
        print(harddisksize)
        break
    else:
        newcat.append(label)
    if label=='cpu model':
        cpumodel=cpumodel+(q[1].text.strip())
        print(cpumodel)
        break
    else:
        newcat.append(label)
    if label=='ram memory installed':
        ram=ram+(q[1].text.strip())
        print(ram)
        break
    else:
        newcat.append(label)
    if label=='operating system':
        operating=operating+(q[1].text.strip())
        print(operating)
        break
    else:
        newcat.append(label)
    if label=='special features':
        special=special+(q[1].text.replace(",","/").replace("See more"," ").strip())
        print(special)
        break
    else:
        newcat.append(label)
    if label=='graphics description':
        graphicdescription=graphicdescription+(q[1].text.replace(",","/").replace("See more"," ").strip())
        print(graphicdescription)
        break
    else:
        newcat.append(label)
# Out:
# Integrated

# %%
with open('amazon.csv','w',encoding='utf8') as fd:
    fd.write('laptopname,brandname,modelname,screensize,color,harddisk,cpumodel, ram,operating,special,graphicdescription,agerangedescription,material,storagevolume,amazonprice in (LE),ratingnumber,deliverytype,amazongetlink,amazon_rating_link\n')
    counter=0
    for n in range(numberofpages):
        while True:
            amazon_get=requests.get(f"https://www.amazon.eg/-/en/s?k=laptops&page={n}&pages=2&pages=31EO2IWBOQN68A&qid=1735816414&sprefix=laptop%2Caps%2C125&ref=sr_pg_{n}")
            if amazon_get:
                print("Sucessful")
                break
            else:
                amazon_get=requests.get(f"https://www.amazon.eg/-/en/s?k=laptops&page={n}&pages=2&pages=31EO2IWBOQN68A&qid=1735816414&sprefix=laptop%2Caps%2C125&ref=sr_pg_{n}")
                print("trying again")
        print(f"Scraping page {n+1}")  
        soup=BeautifulSoup(amazon_get.text,"html.parser")
        trial=soup.find_all('div',attrs={'class':'puis-card-container s-card-container s-overflow-hidden aok-relative puis-expand-height puis-include-content-margin puis puis-v1mhuqsk2j2j3x2l2guv52idafz s-latency-cf-section puis-card-border'})  
        for i in range(len(trial)):
            #laptop name
            amazonname=trial[i].find('h2',attrs={'class':'a-size-base-plus a-spacing-none a-color-base a-text-normal'})
            if amazonname:
                laptopname=amazonname['aria-label'].replace(',',' and').strip()
            else:
                print("not available")
            #laptop link
            link=trial[i].find_all('a',attrs={'class':'a-link-normal s-line-clamp-4 s-link-style a-text-normal'})
            amazon=link[0] 
            amazonlink=amazon.attrs
            amazongetlink='https://www.amazon.eg/'+amazonlink['href'].strip()
            
            #rating link
            ratinglink=trial[i].find('a',attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style'})
            if ratinglink is not None:
                amazon_rating_link='https://www.amazon.eg/'+ratinglink['href'].strip()
            else:
                amazon_rating_link='not available'
                #product
            while True:
                productlink=requests.get(amazongetlink)
                if productlink:
                    print("sucessful")
                    break
                else:
                    print("trying again")
                    productlink=requests.get(amazongetlink)           
            productsoup=BeautifulSoup(productlink.text,'html.parser')
            new2=productsoup.find('div',attrs={'class':'a-expander-collapsed-height a-row a-expander-container a-spacing-none a-expander-partial-collapse-container'})
            if new2:
                new3=new2.find_all('tr')
            else:
                print(new2)
            modelname=""
            newcat=[]
            brandnamee=""
            model=""
            screensize=""
            color=""
            harddisksize=""
            cpumodel=""
            ram=""
            operating=""
            special=""
            material=""
            graphicdescription=""
            agerangedescription=""
            storagevolume=""
            for l in range(len(new3)):
                q=new3[l].find_all('td')
                label=q[0].text.strip().lower()    
                #brandname
                if label=='brand name':
                    brandnamee=brandnamee+(q[1].text.strip())
                elif label == 'model name':
                    model=model+(q[1].text.strip())
                elif label=='screen size':
                    screensize=screensize+(q[1].text.strip())
                elif label=='color':
                    color=color+(q[1].text.strip())
                elif label=='hard disk size':
                    harddisksize=harddisksize+(q[1].text.strip())
                elif label=='cpu model':
                    cpumodel=cpumodel+(q[1].text.strip())
                elif label=='ram memory installed':
                    ram=ram+(q[1].text.strip())
                elif label=='operating system':
                    operating=operating+(q[1].text.strip())
                elif label=='special features':
                    special=special+(q[1].text.replace(",","/").replace("See more"," ").strip())
            
                elif label=='graphics description':
                    graphicdescription=graphicdescription+(q[1].text.replace(",","/").replace("See more"," ").strip())
                elif label=='age range description':
                    agerangedescription=agerangedescription+(q[1].text.replace(",","/").replace("See more"," ").strip())
                elif label=='material':
                    material=material+(q[1].text.replace(",","/").replace("See more"," ").strip())
                elif label=='storage volume':
                    storagevolume=storagevolume+(q[1].text.replace(",","/").replace("See more"," ").strip())
                else:
                    continue     
                    #price
            price=trial[i].find('span',attrs={'class':'a-price'})
            if price:
                laptop_price=price.find_all('span',attrs={'class':'a-offscreen'})
            else:
                print('Not availble')
            if laptop_price and laptop_price is not None:
                edited=laptop_price[0].text.replace('\u200f',' ')
                laptopfixedprice=edited.replace('\xa0',' ')
                amazon_price1=laptopfixedprice.replace('EGP',' ').strip()
                amazonprice0=amazon_price1.replace(',','').strip()
                amazonprice=float(amazonprice0)
            else:
                print("not available")
        #rating
            rating=trial[i].find_all('span',attrs={'class':'a-size-base s-underline-text'})
            if rating:
                    ratingnumber=rating[0].text.replace(",","").strip()
            else:
                    ratingnumber=0
                #delivery type
            subscription=trial[i].find_all('div',attrs={'class':'a-row a-color-base udm-primary-delivery-message'})
            if subscription:
                    deliverytype=subscription[0].text.strip()
            else:
                    deliverytype='not available'
                #product
            fd.write(f"\"{laptopname}\",\"{brandnamee}\",\"{model}\",\"{screensize}\",\"{color}\",\"{harddisksize}\",\"{cpumodel}\",\"{ ram}\",\"{ operating}\",\"{ special}\",\"{ graphicdescription}\",\"{agerangedescription}\",\"{material}\",\"{storagevolume}\",\"{amazonprice}\",\"{ratingnumber}\",\"{deliverytype}\",\"{amazongetlink}\",\"{amazon_rating_link}\"\n")
# Out:
# Sucessful
# Scraping page 1
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# Sucessful
# Scraping page 2
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# ...

# %%
newcat
# Out:
# ['age range description',
#  'material',
#  'storage volume',
#  'item dimensions d x w x h',
#  'recommended uses for product',
#  'backpack design',
#  'subject character']

# %%
df=pd.read_csv("amazon.csv")
df
# Out:
#                                             laptopname           brandname  \
# 0    Dell Vostro 3520 Laptop - 12th Intel Core i5-1...                Dell
# 1    ASUS VivoBook 15 Laptop and Processor-Intel Ce...                ASUS
# 2    Lenovo IdeaPad Slim 3 15IRH8 Intel Core i5-134...              Lenovo
# 3    Dell Inspiron 3520 Laptop - 12th Intel Core i3...                Dell
# 4    HP Victus Gaming Laptop (15-fb1004ne) and CPU:...                  HP
# ..                                                 ...                 ...
# 331  KROSER Rolling Laptop Bag Premium Wheeled Brie...             Add-Ons
# 332  American Tourister NOBLETON Laptop BACKPACK Black  American Tourister
# 333  Samsonite unisex-adult #Value! Luggage- Suitca...  American Tourister
# 334  MOSISO Laptop Tote Bag Compatible with MacBook...  American Tourister
# 335  Laptop Backpack for Men and Women with 17.3inc...  American Tourister
#
# ...
