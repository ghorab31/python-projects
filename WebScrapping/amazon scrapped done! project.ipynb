# %%
import requests
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
amazon_get=requests.get("https://www.amazon.eg/-/en/s?k=laptops&page=1&pages=2&pages=31EO2IWBOQN68A&qid=1735816414&sprefix=laptop%2Caps%2C125&ref=sr_pg_1")
amazon_get
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(amazon_get.text,"html.parser")
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-ae"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <!-- sp:end-feature:csm:head-open-part2 -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
trial=soup.find_all('div',attrs={'class':'puis-card-container s-card-container s-overflow-hidden aok-relative puis-expand-height puis-include-content-margin puis puis-v1mhuqsk2j2j3x2l2guv52idafz s-latency-cf-section puis-card-border'})
trial
# Out:
# [<div class="puis-card-container s-card-container s-overflow-hidden aok-relative puis-expand-height puis-include-content-margin puis puis-v1mhuqsk2j2j3x2l2guv52idafz s-latency-cf-section puis-card-border" data-cy="asin-faceout-container" data-dib-asin="B0CQFCNBT4" data-dib-organic="true"><div class="a-section a-spacing-base"><div class="s-product-image-container aok-relative s-text-center s-image-overlay-grey puis-image-overlay-grey s-padding-left-small s-padding-right-small puis-spacing-small s-height-equalized puis puis-v1mhuqsk2j2j3x2l2guv52idafz" data-cy="image-container"><span class="rush-component" data-component-type="s-product-image" data-render-id="r2w28kuv4as40e2pwronyxyf3mv" data-version-id="v1mhuqsk2j2j3x2l2guv52idafz"><a class="a-link-normal s-no-outline" href="/-/en/Dell-Vostro-3520-Laptop-FingerPrint/dp/B0CQFCNBT4" tabindex="-1"><div class="a-section aok-relative s-image-square-aspect"><img alt='Dell Vostro 3520 Laptop - 12th Intel Core i5-1235U 10-Cores, 8GB RAM, 512G
# ...

# %%
link=trial[0].find_all('a',attrs={'class':'a-link-normal s-line-clamp-4 s-link-style a-text-normal'})

# %%
##link
amazon=link[0] 
amazonlink=amazon.attrs
amazongetlink='https://www.amazon.eg/'+amazonlink['href']
amazongetlink
# Out:
# 'https://www.amazon.eg//-/en/Dell-Vostro-3520-Laptop-FingerPrint/dp/B0CQFCNBT4'

# %%
#name
amazonname=trial[0].find('h2',attrs={'class':'a-size-base-plus a-spacing-none a-color-base a-text-normal'})
laptopname=amazonname['aria-label'].replace(',',' and')
laptopname
# Out:
# 'Dell Vostro 3520 Laptop - 12th Intel Core i5-1235U 10-Cores and 8GB RAM and 512GB SSD and Intel UHD Graphics and 15.6" FHD (1920 x 1080) 120Hz 250 nits Anti-Glare and FingerPrint and Ubuntu - Carbon Black'

# %%
amazonname.text
# Out:
# 'Dell Vostro 3520 Laptop - 12th Intel Core i5-1235U 10-Cores, 8GB RAM, 512GB SSD, Intel UHD Graphics, 15.6" FHD (1920 x 1080) 120Hz 250 nits Anti-Glare, FingerPrint, Ubuntu - Carbon Black'

# %%
#ratingnumber
rating=trial[0].find_all('span',attrs={'class':'a-size-base s-underline-text'})
ratingnumber=int(rating[0].text)
ratingnumber
# Out:
# 19

# %%
## Amazon ratingLINK
ratinglink=trial[0].find('a',attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style'})
amazon_rating_link='https://www.amazon.eg/'+ratinglink['href']
amazon_rating_link
# Out:
# 'https://www.amazon.eg//-/en/Dell-Vostro-3520-Laptop-FingerPrint/dp/B0CQFCNBT4#customerReviews'

# %%
price=trial[0].find('span',attrs={'class':'a-price'})
laptop_price=price.find('span',attrs={'class':'a-offscreen'})
edited=laptop_price.text.replace('\u200f',' ')
laptopfixedprice=edited.replace('\xa0',' ')
amazon_price1=laptopfixedprice.replace('EGP',' ').strip()
amazonprice0=amazon_price1.replace(',','').strip()
amazonprice=float(amazonprice0)

# %%
subscription=trial[0].find_all('div',attrs={'class':'a-row a-color-base udm-primary-delivery-message'})
deliverytype=subscription[0].text.strip()
deliverytype
# Out:
# 'FREE delivery'

# %%
productlink=requests.get(amazongetlink)
productsoup=BeautifulSoup(productlink.text,'html.parser')
productdata=productsoup.find_all('div',attrs={'class':'a-section a-spacing-base'})
productdata
# Out:
# [<div class="a-section a-spacing-base" id="twister-plus-tool-tip-subtotal-section"> <div class="a-fixed-right-grid a-spacing-small" id="tp-tool-tip-subtotal-price-block"><div class="a-fixed-right-grid-inner" style="padding-right:110px"> <div class="a-fixed-right-grid-col a-col-left" style="padding-right:4%;float:left;"> <span class="a-size-base" id="display-string">Subtotal</span> </div> <div class="a-text-right a-fixed-right-grid-col a-col-right" style="width:110px;margin-right:-110px;float:left;"> <span class="a-size-medium twister-plus-subtotal-price-template"> <span class="a-size-medium a-price-symbol" id="tp-tool-tip-subtotal-price-currency-symbol">EGP</span><!-- Adding space based on
#              hasSpace--> <!--To remove span
#              space--><!--To remove span
#              space--><span class="a-size-medium a-text-bold"><!--To
# ...

# %%
pagenumber=soup.find('span',attrs={'class':'s-pagination-item s-pagination-disabled'})
numberofpages=int(pagenumber.text)
numberofpages
# Out:
# 7

# %%
productlink=requests.get(amazongetlink)
productsoup=BeautifulSoup(productlink.text,'html.parser')
productdata=productsoup.find_all('div',attrs={'class':'a-section a-spacing-small a-spacing-top-small'})
specs=""
productcategory=""
catlist=[]
listtdata=[]
testing=("")
for i in range(len(productdata)):
    products=productdata[i].find_all('span',attrs={'class':'a-size-base po-break-word'})
    for p in range(len(products)):
                specs=specs+'/'+products[p].text
                specs=specs.replace(",","").strip()
                product_data=products[p].text.strip()
                listtdata.append(product_data)

    for c in range(len(category)):
                category=productsoup.find_all('td',attrs={'class':'a-span3'})
                categ_name=category[c].text.strip()
                catlist.append(categ_name)
                productcategory=productcategory+categ_name+":"+product_data+"/"
    for n,d in zip(catlist,listtdata):
        testing=testing+" "+n+":"+d + "\n"
print(testing)
# Out:
#  Brand Name:ASUS
#  Model Name:FA506NC-HN005W
#  Screen Size:15.6 Inches
#  Color:Black
#  Hard Disk Size:512 GB
#  CPU Model:Ryzen 5
#  RAM Memory Installed:8 GB
#  Operating System:Windows 11
#  Special Features:Anti Glare Coating
#  Graphics Description:Dedicated

# %%
with open('newepic1.csv','w',encoding='utf8') as fd:
    fd.write('laptopname,amazonprice in (LE),specs,ratingnumber,deliverytype,amazongetlink,amazon_rating_link\n')
    counter=0
    for n in range(numberofpages):
        print(f"Scraping page {n+1}")
        amazon_get=requests.get(f"https://www.amazon.eg/-/en/s?k=laptops&page={n}&pages=2&pages=31EO2IWBOQN68A&qid=1735816414&sprefix=laptop%2Caps%2C125&ref=sr_pg_{n}")
        soup=BeautifulSoup(amazon_get.text,"html.parser")
        trial=soup.find_all('div',attrs={'class':'puis-card-container s-card-container s-overflow-hidden aok-relative puis-expand-height puis-include-content-margin puis puis-v1mhuqsk2j2j3x2l2guv52idafz s-latency-cf-section puis-card-border'})
        for i in range(len(trial)):
            #laptop name
            amazonname=trial[i].find('h2',attrs={'class':'a-size-base-plus a-spacing-none a-color-base a-text-normal'})
            if amazonname:
                laptopname=amazonname['aria-label'].replace(',',' and').strip()
            else:
                print("not available")
            #price
            price=trial[i].find('span',attrs={'class':'a-price'})
            if price:
                laptop_price=price.find_all('span',attrs={'class':'a-offscreen'})
            else:
                print('Not availble')
            if laptop_price and laptop_price is not None:
                edited=laptop_price[0].text.replace('\u200f',' ')
                laptopfixedprice=edited.replace('\xa0',' ')
                amazon_price1=laptopfixedprice.replace('EGP',' ').strip()
                amazonprice0=amazon_price1.replace(',','').strip()
                amazonprice=float(amazonprice0)
            else:
                print("not available")
            
            #laptop link
            link=trial[i].find_all('a',attrs={'class':'a-link-normal s-line-clamp-4 s-link-style a-text-normal'})
            amazon=link[0] 
            amazonlink=amazon.attrs
            amazongetlink='https://www.amazon.eg/'+amazonlink['href'].strip()
            #rating link
            ratinglink=trial[i].find('a',attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style'})
            if ratinglink is not None:
                amazon_rating_link='https://www.amazon.eg/'+ratinglink['href'].strip()
            else:
                amazon_rating_link='not available'
                #product
            productlink=requests.get(amazongetlink)
            productsoup=BeautifulSoup(productlink.text,'html.parser')
            productdata=productsoup.find_all('div',attrs={'class':'a-section a-spacing-small a-spacing-top-small'})
            specs=""
            productcategory=""
            catlist=[]
            listtdata=[]
            testing=("")
            for i in range(len(productdata)):
                products=productdata[i].find_all('span',attrs={'class':'a-size-base po-break-word'})
                for p in range(len(products)):
                            specs=specs+'/'+products[p].text
                            specs=specs.replace(",","").strip()
                            product_data=products[p].text.strip()
                            if product_data:
                                listtdata.append(product_data)
                            else:
                                print("not availble")  
                category=productsoup.find_all('td',attrs={'class':'a-span3'})
                for c in range(len(category)):
                            categ_name=category[c].text.strip()
                            if categ_name:
                                catlist.append(categ_name)
                            else:
                                print("not availble")
                            productcategory=productcategory+categ_name+":"+product_data+"/"
                for n,d in zip(catlist,listtdata):
                    testing=testing+" "+n+":"+d + "\n"
            #rating
            rating=trial[i].find_all('span',attrs={'class':'a-size-base s-underline-text'})
            if rating:
                    ratingnumber=rating[0].text.replace(",","").strip()
            else:
                    ratingnumber=0
                #delivery type
            subscription=trial[i].find_all('div',attrs={'class':'a-row a-color-base udm-primary-delivery-message'})
            if subscription:
                    deliverytype=subscription[0].text.strip()
            else:
                    deliverytype='not available'
                #product
            print(f'{deliverytype},{amazon_get}.{testing}')
            counter=i+0
            fd.write(f"\"{laptopname}\",\"{amazonprice}\",\"{testing}\",\"{ratingnumber}\",\"{deliverytype}\",\"{amazongetlink}\",\"{amazon_rating_link}\"\n")
# Out:
# Scraping page 1
# FREE delivery,<Response [200]>. Brand Name:Dell
#  Model Name:Vostro 3520
#  Screen Size:15.6 Inches
#  Color:Carbon Black
#  Hard Disk Size:512 GB
#  CPU Model:Core i5-1235U
#  RAM Memory Installed:8 GB
#  Operating System:Ubuntu
#  Special Features:Integrated
#
# FREE delivery,<Response [200]>. Brand Name:ASUS
#  Model Name:X515M-BR001W
#  Screen Size:15.6 Inches
#  Color:Gray
#  Hard Disk Size:256 GB
#  CPU Model:Celeron N4020
#  RAM Memory Installed:4 GB
#  Operating System:Windows 11 Home
#  Special Features:Integrated
#
# FREE delivery,<Response [200]>. Brand Name:HP
#  Model Name:Victus
#  Screen Size:15.6 Inches
#  Color:Black
#  RAM Memory Installed:16 GB
#  Operating System:Windows 11
#  Special Features:Dedicated
#  Graphics Description:SSD
#  Hard Disk Description:1920x1080
#
# FREE delivery,<Response [200]>. Brand Name:ASUS
#  Model Name:D1502YA-NJ007W
#  Screen Size:15.6 Inches
#  Color:Black
#  Hard Disk Size:512 GB
#  CPU Model:Ryzen 7
# ...

# %%
df=pd.read_csv("newepic1.csv")
df
# Out:
#                                             laptopname amazonprice in (LE)  \
# 0    Dell Vostro 3520 Laptop - 12th Intel Core i5-1...             19799.0
# 1    ASUS VivoBook 15 Laptop and Processor-Intel Ce...             11999.0
# 2    HP Victus Gaming Laptop (15-fb1004ne) and CPU:...             32949.0
# 3    ASUS Vivobook 15 and AMD Ryzen 7 7730U and 8GB...             22730.0
# 4    ASUS TUF Gaming A15 FA506NFR-HN007W Gaming Lap...             31800.0
# ..                                                 ...                 ...
# 293  BAGSMART 15.6 17.3 Inch Laptop Bag and Briefca...              7980.0
# 294           Samsonite vigon ii briefcase 15.6 black"            14363.05
# 295  Targus Mobile-VIP 4-Wheeled Business & Overnig...              3990.0
# 296  Dual USB Wired Game Controller for PC and Lapt...               394.0
# 297  Mobigon Slim Laptop Backpack Fits For 15.6 Inc...               540.0
#
# ...
